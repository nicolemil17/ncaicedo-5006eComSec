# %% [markdown]
# # Deber 6: Practica de Google Analytics
# Nicole Caicedo   00213150
# ## Preguntas de investigacion
#
# 1. ¿Cuál es el número total de usuarios y usuarios nuevos que accedieron a la tienda en el rango de fechas? ¿Cuáles son los 10 países que más tráfico generaron?
#
# - 793 mil usuarios en total y 748 mil usuarios nuevos.
#
# 2. ¿Cuáles son las tres resoluciones de pantalla más frecuentes para accederal sitio web y su volumen de usuarios?
#
# - 1920X1080
# - 390X844
# - 412X915
#
# 3. ¿Cuántas visitas de tráfico directo se produjeron el día 7 de diciembre de 2022?
#
# - 18774 visitas de trafico directo.
#
# 4. ¿Qué porcentaje de visitantes regresan al sitio, en comparación con los visitantes nuevos?
#
# - De 748mil usuarios nuevos , 134mil son recurrentes . Por lo que representa solo el 17.91% de los usuarios son recurrentes
#
#
# 5. ¿Cuántas sesiones se generaron desde el canal de Email y el canal Social orgánico durante el rango de fechas
# analizado?
#
# - Desde email se generan 11413 sesiones y desde social organico 9176 sesiones.
#
# 6. ¿Cuáles son los diez dispositivos que más tráfico generaron al sitio web durante el periodo de análisis?
#
# - Safari
# - Chrome
# - iPhone
# - ChromeBook
# - Pixel 7 Pro
# - Pixel 6 Pro
# - Edge
# - Ipad
# - not set
# - Pixel 7
#
# 7. Menciona las 5 consultas de búsqueda que generaron la mayor cantidad de tráfico en el sitio.
#
# - youtube merch
# - youtube store
# - google t shirt
# - google merchandise store
# - youtube shop
# - google backback
#
#
# 8. ¿Qué 10 idiomas son los que generaron mayor cantidad de usuarios en el rango de fechas analizadas? ¿Qué idioma generó el mayor tiempo de interacción en el sitio web?
# - English , chinese, spanish, french, japanese, korean, portuguese , Russian and Turkish . El idioma japones con una interaccion media de 2min 21s.
#
# 9. ¿Cuáles son los 5 sistemas operativos que generar la mayor cantidad de tráfico al sitio web?
#
# ![image.png](attachment:image.png)
#
#
# 10. ¿Cuáles son las 10 ciudades que más tráfico generaron hacia la tienda? ¿Qué rango de edad es el que genera
# más tráfico? Menciona las 10 categorías de intereses en las que se clasifica a  los visitantes de la tienda durante el
# periodo de análisis.
#
# - Not set, New York,Toronto , San Jose, Los Angeles, Mountain View, Chicago, San Francisco, Sunnyvale, Montreal
# - de 25 a 34 anios
# - Technology/Technophiles, Media & Entertainment/Movie Lovers,  Media & Entertainment/Movie Lovers, Banking & Finance/Avid Investors, Shoppers/Value Shoppers, Lifestyles & Hobbies/Shutterbugs, Lifestyles & Hobbies/Shutterbugs,  Lifestyles & Hobbies/Shutterbugs, Media & Entertainment/Music Lovers.
#
# 11. ¿Qué dos campañas de Google Ads, con más de mil clics, generaron los mayores retornos de inversión publicitaria? ¿Cuáles dos fueron las campañas más costosas y cuáles fueron las que generaron mayor cantidad de ingresos monetarios?
#
# -
#
#
# 12. ¿Qué valor monetario generó el sitio durante el periodo de análisis? ¿Cuál fue la tasa de conversión y el valor
# promedio de los pedidos?
#
# - Tuvo un total de ingresos de 1.9M de dolares.
# - El valor promedio de los pedidos fue de 2.54 dolares
