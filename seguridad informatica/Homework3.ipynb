# %% [markdown]
# # Homework 3
# ## Web Security picoCTF evidence
# Nicole Caicedo    00213150

# %% [markdown]
# ### 1) Cookies
# ![imagen.png](attachment:7d49dcf1-b3a8-43d1-899b-83e454fa92d8.png)

# %% [markdown]
# ### 2) Scavenger Hunt
# ![imagen.png](attachment:43217e74-8f1b-48d0-869d-ce9811920c1f.png)
# ![imagen.png](attachment:5ae7034c-caad-4515-bad2-79feb08b70c4.png)
# ![imagen.png](attachment:b8a32ecc-29f7-48e2-a068-14bf16269210.png)
# ![imagen.png](attachment:a2042347-334d-48d9-8eec-a5cb7f1da2dc.png)
# ![imagen.png](attachment:5c387c81-5708-417c-9c2c-7f5719999587.png)
# ![imagen.png](attachment:588cd584-cf27-4eba-ad8f-605783a06782.png)

# %% [markdown]
# ### 3) findme
# ![imagen.png](attachment:8b15fe34-33d8-491c-9b75-9326c03586fc.png)
# ![imagen.png](attachment:af85680c-f7dd-4db9-8bf9-08ca510694bf.png)
# ![imagen.png](attachment:e9669620-7e19-4a56-879f-e3a47e5a10e2.png)
# ![imagen.png](attachment:e2fd57c3-28fb-4e29-acbf-56df07e617b9.png)
# ![imagen.png](attachment:265a6d26-f3a3-4ce4-84a7-5fc4be56b9bf.png)
# ![imagen.png](attachment:54cc5353-8157-42f5-b148-d9a982b1a116.png)
# ![imagen.png](attachment:91ab7e67-7530-4093-a118-ca050723516c.png)

# %% [markdown]
# ### 4) Inspect HTML
# ![imagen.png](attachment:cf9878aa-e114-4048-b0d3-c731e1bed850.png)

# %% [markdown]
# ### 5) It is my birthday
# ![imagen.png](attachment:92f55826-fd92-4749-ac2d-c42fdbe084fe.png)
# ![imagen.png](attachment:f962bad3-9a11-42a6-b5cb-770f1e3c0b06.png)
# ![imagen.png](attachment:8fb34422-21e6-4a69-80af-2d3bf413622e.png)
# ![imagen.png](attachment:a8461cf6-7750-4bed-9753-a381d78b4bf4.png)

# %% [markdown]
# ### 6) Local authority
# ![imagen.png](attachment:a86a7cf1-9350-4432-bab0-65e131095f5d.png)
# ![imagen.png](attachment:a19b8951-f1d6-4bd2-9731-20532166ba33.png)
# ![imagen.png](attachment:9b350d9c-5255-48cd-bfe5-ce8afbc0c409.png)

# %% [markdown]
# ### 7) Login
# ![imagen.png](attachment:6e3a5da6-7459-4d90-b950-a7d7386ece16.png)
# ![imagen.png](attachment:54a63445-f31c-40b4-a43f-be88a0925c00.png)
# ![imagen.png](attachment:efc25034-acbe-40f4-9671-9d987ca18534.png)

# %% [markdown]
# ### 8) logon
# ![imagen.png](attachment:d4d18a80-f6a6-4d3d-804e-80ed0b7d4543.png)
# ![imagen.png](attachment:91801633-748f-4c98-bdfb-f18cd0be4209.png)

# %% [markdown]
# ### 9) Search  source
# ![imagen.png](attachment:56cced63-2910-46ce-9a56-98f7969f4998.png)
# ![imagen.png](attachment:39367bf9-28a3-4822-a4c8-f3cd6c9cad75.png)

# %% [markdown]
# ### 10) where are the robots
# ![imagen.png](attachment:e03d4f26-86db-4d68-b458-3f4d8a62d7b6.png)
# ![imagen.png](attachment:47b57386-a139-40aa-89da-a3704f3d6dc1.png)
